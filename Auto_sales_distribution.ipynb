# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datasets import load_dataset
import scipy 
import ast
import seaborn as sns

# %%
df=pd.read_csv('C:/Users/Cornelius/Desktop/project_code/New folder/Auto Sales data.csv')
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10168               36      96.66                1  3479.76
# ...           ...              ...        ...              ...      ...
# 2742        10350               20     112.22               15  2244.40
# 2743        10373               29     137.19                1  3978.51
# 2744        10386               43     125.99                4  5417.57
# 2745        10397               34      62.24                1  2116.16
# 2746        10414               47      65.52                9  3079.44
#
#        ORDERDATE  DAYS_SINCE_LASTORDER    STATUS  PRODUCTLINE  MSRP  \
# 0     24/02/2018                   828   Shipped  Motorcycles    95
# 1     07/05/2018                   757   Shipped  Motorcycles    95
# 2     01/07/2018                   703   Shipped  Motorcycles    95
# 3     25/08/2018                   649   Shipped  Motorcycles    95
# 4     28/10/2018                   586   Shipped  Motorcycles    95
# ...          ...                   ...       ...          ...   ...
# 2742  02/12/2019                  2924   Shipped        Ships    54
# 2743  31/01/2020                  2865   Shipped        Ships    54
# 2744  01/03/2020                  2836  Resolved        Ships    54
# 2745  28/03/2020                  2810   Shipped        Ships    54
# 2746  06/05/2020                  2772   On Hold        Ships    54
#
#      PRODUCTCODE             CUSTOMERNAME             PHONE  \
# 0       S10_1678        Land of Toys Inc.        2125557818
# 1       S10_1678       Reims Collectables        26.47.1555
# 2       S10_1678          Lyon Souveniers  +33 1 46 62 7555
# 3       S10_1678        Toys4GrownUps.com        6265557265
# 4       S10_1678     Technics Stores Inc.        6505556809
# ...          ...                      ...               ...
# 2742    S72_3212    Euro Shopping Channel    (91) 555 94 44
# 2743    S72_3212  Oulu Toy Supplies, Inc.        981-443655
# 2744    S72_3212    Euro Shopping Channel    (91) 555 94 44
# 2745    S72_3212             Alpha Cognac        61.77.6555
# 2746    S72_3212        Gifts4AllAges.com        6175559555
#
#                        ADDRESSLINE1        CITY POSTALCODE  COUNTRY  \
# 0           897 Long Airport Avenue         NYC      10022      USA
# 1                59 rue de l'Abbaye       Reims      51100   France
# 2     27 rue du Colonel Pierre Avia       Paris      75508   France
# 3                78934 Hillside Dr.    Pasadena      90003      USA
# 4                 9408 Furth Circle  Burlingame      94217      USA
# ...                             ...         ...        ...      ...
# 2742             C/ Moralzarzal, 86      Madrid      28034    Spain
# 2743                    Torikatu 38        Oulu      90110  Finland
# 2744             C/ Moralzarzal, 86      Madrid      28034    Spain
# 2745          1 rue Alsace-Lorraine    Toulouse      31000   France
# 2746             8616 Spinnaker Dr.      Boston      51003      USA
#
#      CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0                 Yu             Kwai    Small
# 1            Henriot             Paul    Small
# 2           Da Cunha           Daniel   Medium
# 3              Young            Julie   Medium
# 4             Hirano             Juri   Medium
# ...              ...              ...      ...
# 2742          Freyre            Diego    Small
# 2743       Koskitalo           Pirkko   Medium
# 2744          Freyre            Diego   Medium
# 2745          Roulet          Annette    Small
# 2746         Yoshido             Juri   Medium
#
# [2747 rows x 20 columns]

# %%
df_copy=df.copy()
df_copy
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10168               36      96.66                1  3479.76
# ...           ...              ...        ...              ...      ...
# 2742        10350               20     112.22               15  2244.40
# 2743        10373               29     137.19                1  3978.51
# 2744        10386               43     125.99                4  5417.57
# 2745        10397               34      62.24                1  2116.16
# 2746        10414               47      65.52                9  3079.44
#
#        ORDERDATE  DAYS_SINCE_LASTORDER    STATUS  PRODUCTLINE  MSRP  \
# 0     24/02/2018                   828   Shipped  Motorcycles    95
# 1     07/05/2018                   757   Shipped  Motorcycles    95
# 2     01/07/2018                   703   Shipped  Motorcycles    95
# 3     25/08/2018                   649   Shipped  Motorcycles    95
# 4     28/10/2018                   586   Shipped  Motorcycles    95
# ...          ...                   ...       ...          ...   ...
# 2742  02/12/2019                  2924   Shipped        Ships    54
# 2743  31/01/2020                  2865   Shipped        Ships    54
# 2744  01/03/2020                  2836  Resolved        Ships    54
# 2745  28/03/2020                  2810   Shipped        Ships    54
# 2746  06/05/2020                  2772   On Hold        Ships    54
#
#      PRODUCTCODE             CUSTOMERNAME             PHONE  \
# 0       S10_1678        Land of Toys Inc.        2125557818
# 1       S10_1678       Reims Collectables        26.47.1555
# 2       S10_1678          Lyon Souveniers  +33 1 46 62 7555
# 3       S10_1678        Toys4GrownUps.com        6265557265
# 4       S10_1678     Technics Stores Inc.        6505556809
# ...          ...                      ...               ...
# 2742    S72_3212    Euro Shopping Channel    (91) 555 94 44
# 2743    S72_3212  Oulu Toy Supplies, Inc.        981-443655
# 2744    S72_3212    Euro Shopping Channel    (91) 555 94 44
# 2745    S72_3212             Alpha Cognac        61.77.6555
# 2746    S72_3212        Gifts4AllAges.com        6175559555
#
#                        ADDRESSLINE1        CITY POSTALCODE  COUNTRY  \
# 0           897 Long Airport Avenue         NYC      10022      USA
# 1                59 rue de l'Abbaye       Reims      51100   France
# 2     27 rue du Colonel Pierre Avia       Paris      75508   France
# 3                78934 Hillside Dr.    Pasadena      90003      USA
# 4                 9408 Furth Circle  Burlingame      94217      USA
# ...                             ...         ...        ...      ...
# 2742             C/ Moralzarzal, 86      Madrid      28034    Spain
# 2743                    Torikatu 38        Oulu      90110  Finland
# 2744             C/ Moralzarzal, 86      Madrid      28034    Spain
# 2745          1 rue Alsace-Lorraine    Toulouse      31000   France
# 2746             8616 Spinnaker Dr.      Boston      51003      USA
#
#      CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0                 Yu             Kwai    Small
# 1            Henriot             Paul    Small
# 2           Da Cunha           Daniel   Medium
# 3              Young            Julie   Medium
# 4             Hirano             Juri   Medium
# ...              ...              ...      ...
# 2742          Freyre            Diego    Small
# 2743       Koskitalo           Pirkko   Medium
# 2744          Freyre            Diego   Medium
# 2745          Roulet          Annette    Small
# 2746         Yoshido             Juri   Medium
#
# [2747 rows x 20 columns]

# %%
df_clean=df_copy.drop(columns=['PRODUCTCODE','ADDRESSLINE1','POSTALCODE','ORDERLINENUMBER'])
df_clean
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH    SALES   ORDERDATE  \
# 0           10107               30      95.70  2871.00  24/02/2018
# 1           10121               34      81.35  2765.90  07/05/2018
# 2           10134               41      94.74  3884.34  01/07/2018
# 3           10145               45      83.26  3746.70  25/08/2018
# 4           10168               36      96.66  3479.76  28/10/2018
# ...           ...              ...        ...      ...         ...
# 2742        10350               20     112.22  2244.40  02/12/2019
# 2743        10373               29     137.19  3978.51  31/01/2020
# 2744        10386               43     125.99  5417.57  01/03/2020
# 2745        10397               34      62.24  2116.16  28/03/2020
# 2746        10414               47      65.52  3079.44  06/05/2020
#
#       DAYS_SINCE_LASTORDER    STATUS  PRODUCTLINE  MSRP  \
# 0                      828   Shipped  Motorcycles    95
# 1                      757   Shipped  Motorcycles    95
# 2                      703   Shipped  Motorcycles    95
# 3                      649   Shipped  Motorcycles    95
# 4                      586   Shipped  Motorcycles    95
# ...                    ...       ...          ...   ...
# 2742                  2924   Shipped        Ships    54
# 2743                  2865   Shipped        Ships    54
# 2744                  2836  Resolved        Ships    54
# 2745                  2810   Shipped        Ships    54
# 2746                  2772   On Hold        Ships    54
#
#                  CUSTOMERNAME             PHONE        CITY  COUNTRY  \
# 0           Land of Toys Inc.        2125557818         NYC      USA
# 1          Reims Collectables        26.47.1555       Reims   France
# 2             Lyon Souveniers  +33 1 46 62 7555       Paris   France
# 3           Toys4GrownUps.com        6265557265    Pasadena      USA
# 4        Technics Stores Inc.        6505556809  Burlingame      USA
# ...                       ...               ...         ...      ...
# 2742    Euro Shopping Channel    (91) 555 94 44      Madrid    Spain
# 2743  Oulu Toy Supplies, Inc.        981-443655        Oulu  Finland
# 2744    Euro Shopping Channel    (91) 555 94 44      Madrid    Spain
# 2745             Alpha Cognac        61.77.6555    Toulouse   France
# 2746        Gifts4AllAges.com        6175559555      Boston      USA
#
#      CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0                 Yu             Kwai    Small
# 1            Henriot             Paul    Small
# 2           Da Cunha           Daniel   Medium
# 3              Young            Julie   Medium
# 4             Hirano             Juri   Medium
# ...              ...              ...      ...
# 2742          Freyre            Diego    Small
# 2743       Koskitalo           Pirkko   Medium
# 2744          Freyre            Diego   Medium
# 2745          Roulet          Annette    Small
# 2746         Yoshido             Juri   Medium
#
# [2747 rows x 16 columns]

# %%
df_clean.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH         SALES  \
# count   2747.000000      2747.000000  2747.000000   2747.000000
# mean   10259.761558        35.103021   101.098952   3553.047583
# std       91.877521         9.762135    42.042549   1838.953901
# min    10100.000000         6.000000    26.880000    482.130000
# 25%    10181.000000        27.000000    68.745000   2204.350000
# 50%    10264.000000        35.000000    95.550000   3184.800000
# 75%    10334.500000        43.000000   127.100000   4503.095000
# max    10425.000000        97.000000   252.870000  14082.800000
#
#        DAYS_SINCE_LASTORDER         MSRP
# count           2747.000000  2747.000000
# mean            1757.085912   100.691664
# std              819.280576    40.114802
# min               42.000000    33.000000
# 25%             1077.000000    68.000000
# 50%             1761.000000    99.000000
# 75%             2436.500000   124.000000
# max             3562.000000   214.000000

# %%
pd.DataFrame(df_clean['SALES'].agg(["sum",'max','min','median']))
# Out:
#              SALES
# sum     9760221.71
# max       14082.80
# min         482.13
# median     3184.80

# %%
df_clean['PRODUCTLINE'].unique()
# Out:
# array(['Motorcycles', 'Classic Cars', 'Trucks and Buses', 'Vintage Cars',
#        'Planes', 'Ships', 'Trains'], dtype=object)

# %%
df_prod=pd.DataFrame(df_clean.groupby('PRODUCTLINE')['SALES'].sum().sort_values(ascending=False))
df_prod
# Out:
#                        SALES
# PRODUCTLINE
# Classic Cars      3842868.54
# Vintage Cars      1806675.68
# Trucks and Buses  1111559.19
# Motorcycles       1103512.19
# Planes             969323.42
# Ships              700039.22
# Trains             226243.47

# %%
df_size=pd.DataFrame(df_clean.groupby('DEALSIZE')[['SALES','QUANTITYORDERED']].sum().sort_values(by='SALES',ascending=False))
df_size
# Out:
#                SALES  QUANTITYORDERED
# DEALSIZE
# Medium    5931231.47            51209
# Small     2570033.84            38025
# Large     1258956.40             7194

# %%
grouped_sales = df_clean.groupby('DEALSIZE')['SALES'].sum()
grouped_quantity=df_clean.groupby('DEALSIZE')['QUANTITYORDERED'].sum()

fig, ax = plt.subplots(1, 2)
fig.set_size_inches((12,5))
# Pie chart for SALES
ax[0].pie(grouped_sales, startangle=90, autopct="%1.2f%%",labels=grouped_sales.index)
ax[0].set_title("Percentage of Total Sales by Each Product size")
# Pie chart for QUANTITYORDERED
ax[1].pie(grouped_quantity, startangle=90, autopct="%1.2f%%",labels=grouped_quantity.index)
ax[1].set_title('Percentage of Quantitty Sold by Each Product Size')

plt.show()
plt.tight_layout()

# %%
#Sales Disbution and qunatiti distribution 
sns.displot(df_clean["SALES"],kind='kde',fill=True, label="Sales Distribution",color="green")
plt.title("Sales Distribution")
sns.displot(df_clean['QUANTITYORDERED'],kind='kde',fill=True,color="Yellow")
plt.title("Quantity Ordered Distribution")
# Out:
# Text(0.5, 1.0, 'Quantity Ordered Distribution')

# %%
sns.boxplot(data=df_clean,x='SALES',y="DEALSIZE")
plt.title("Sales Distribution by Product Size")
ticks_x=plt.FuncFormatter(lambda y,pos: f'${int(y/1000)}k')
plt.gca().xaxis.set_major_formatter(ticks_x)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2747 entries, 0 to 2746
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ORDERNUMBER           2747 non-null   int64
#  1   QUANTITYORDERED       2747 non-null   int64
#  2   PRICEEACH             2747 non-null   float64
#  3   SALES                 2747 non-null   float64
#  4   ORDERDATE             2747 non-null   object
#  5   DAYS_SINCE_LASTORDER  2747 non-null   int64
#  6   STATUS                2747 non-null   object
#  7   PRODUCTLINE           2747 non-null   object
#  8   MSRP                  2747 non-null   int64
#  9   CUSTOMERNAME          2747 non-null   object
#  10  PHONE                 2747 non-null   object
#  11  CITY                  2747 non-null   object
#  12  COUNTRY               2747 non-null   object
#  13  CONTACTLASTNAME       2747 non-null   object
#  14  CONTACTFIRSTNAME      2747 non-null   object
#  15  DEALSIZE              2747 non-null   object
# dtypes: float64(2), int64(4), object(10)
# memory usage: 343.5+ KB

# %%
#sales for each product line  in each country 
df_product_line=df_clean.pivot_table(values="SALES",columns="PRODUCTLINE",index='COUNTRY',aggfunc="sum")
df_product_line
# Out:
# PRODUCTLINE  Classic Cars  Motorcycles     Planes      Ships    Trains  \
# COUNTRY
# Australia       193085.54     89968.76   74853.87    4159.76   1681.35
# Austria         101459.47     26047.66   17860.44    9024.73       NaN
# Belgium          20136.96          NaN    5624.79   31708.01   9017.26
# Canada           61623.22      4177.49   25510.07   40309.01       NaN
# Denmark         157182.48          NaN    7586.45   38697.26  11476.33
# Finland         153552.24     47866.72   34375.13   29808.44   5117.05
# France          388951.20    226390.31  108155.51   66486.67  27340.80
# Germany         148315.00      7497.50   23001.26    5501.00   5043.42
# Ireland          31688.82      4953.20   11784.36        NaN   3112.60
# Italy           128576.65      7567.80   98185.65   17703.54   6274.96
# Japan            47271.49     26536.41   49176.96   18860.02   3523.67
# Norway          134787.37     51768.63   29500.70        NaN  11310.36
# Philippines      53112.09     18061.68   20906.87        NaN       NaN
# Singapore       132890.44      4175.60        NaN   14155.52  13278.71
# Spain           476165.15     74634.82   89985.51  124459.97  43370.18
# Sweden           69088.06     15567.25    8899.60   30915.89   3807.68
# Switzerland     117713.56          NaN        NaN        NaN       NaN
# UK              159377.70     40802.81   41163.51   72959.17  12635.54
# USA            1267891.10    457495.55  322752.74  195290.23  69253.56
#
# PRODUCTLINE  Trucks and Buses  Vintage Cars
# COUNTRY
# Australia            77318.50     189555.32
# Austria              20472.75      27197.48
# Belgium                   NaN      41925.60
# Canada               51945.98      40512.79
# Denmark               9588.82      21105.81
# Finland              40479.33      18383.00
# France              116982.22     176609.81
# Germany              10178.00      20935.91
# Ireland               3983.05       2234.40
# Italy                 5914.97     110450.74
# Japan                13349.44      29449.82
# Norway               37075.64      43021.00
# Philippines               NaN       1935.09
# Singapore            89027.68      34960.46
# Spain               177556.78     229514.51
# Sweden               47931.27      33804.46
# Switzerland               NaN           NaN
# UK                   28142.99     123798.74
# USA                 381611.77     661280.74

# %%
df_product_line.loc["TOTAl"]=df_product_line.sum()
df_product_line
# Out:
# PRODUCTLINE  Classic Cars  Motorcycles     Planes      Ships     Trains  \
# COUNTRY
# Australia       193085.54     89968.76   74853.87    4159.76    1681.35
# Austria         101459.47     26047.66   17860.44    9024.73        NaN
# Belgium          20136.96          NaN    5624.79   31708.01    9017.26
# Canada           61623.22      4177.49   25510.07   40309.01        NaN
# Denmark         157182.48          NaN    7586.45   38697.26   11476.33
# Finland         153552.24     47866.72   34375.13   29808.44    5117.05
# France          388951.20    226390.31  108155.51   66486.67   27340.80
# Germany         148315.00      7497.50   23001.26    5501.00    5043.42
# Ireland          31688.82      4953.20   11784.36        NaN    3112.60
# Italy           128576.65      7567.80   98185.65   17703.54    6274.96
# Japan            47271.49     26536.41   49176.96   18860.02    3523.67
# Norway          134787.37     51768.63   29500.70        NaN   11310.36
# Philippines      53112.09     18061.68   20906.87        NaN        NaN
# Singapore       132890.44      4175.60        NaN   14155.52   13278.71
# Spain           476165.15     74634.82   89985.51  124459.97   43370.18
# Sweden           69088.06     15567.25    8899.60   30915.89    3807.68
# Switzerland     117713.56          NaN        NaN        NaN        NaN
# UK              159377.70     40802.81   41163.51   72959.17   12635.54
# USA            1267891.10    457495.55  322752.74  195290.23   69253.56
# TOTAl          3842868.54   1103512.19  969323.42  700039.22  226243.47
#
# PRODUCTLINE  Trucks and Buses  Vintage Cars
# COUNTRY
# Australia            77318.50     189555.32
# Austria              20472.75      27197.48
# Belgium                   NaN      41925.60
# Canada               51945.98      40512.79
# Denmark               9588.82      21105.81
# Finland              40479.33      18383.00
# France              116982.22     176609.81
# Germany              10178.00      20935.91
# Ireland               3983.05       2234.40
# Italy                 5914.97     110450.74
# Japan                13349.44      29449.82
# Norway               37075.64      43021.00
# Philippines               NaN       1935.09
# Singapore            89027.68      34960.46
# Spain               177556.78     229514.51
# Sweden               47931.27      33804.46
# Switzerland               NaN           NaN
# UK                   28142.99     123798.74
# USA                 381611.77     661280.74
# TOTAl              1111559.19    1806675.68

# %%
# Total SALES and Quantity Orederd by Productline and country
df_s=pd.DataFrame(df_clean.groupby('PRODUCTLINE')['SALES'].sum().sort_values(ascending=False))
df_q=df_p=pd.DataFrame(df_clean.groupby('PRODUCTLINE')['QUANTITYORDERED'].sum().sort_values(ascending=False))
df_s
# Out:
#                        SALES
# PRODUCTLINE
# Classic Cars      3842868.54
# Vintage Cars      1806675.68
# Trucks and Buses  1111559.19
# Motorcycles       1103512.19
# Planes             969323.42
# Ships              700039.22
# Trains             226243.47

# %%
df_q
# Out:
#                   QUANTITYORDERED
# PRODUCTLINE
# Classic Cars                33373
# Vintage Cars                20059
# Motorcycles                 11080
# Planes                      10636
# Trucks and Buses            10579
# Ships                        7989
# Trains                       2712

# %%
df_merge=df_s.merge(df_q,on="PRODUCTLINE",how='left')
df_merge
# Out:
#                        SALES  QUANTITYORDERED
# PRODUCTLINE
# Classic Cars      3842868.54            33373
# Vintage Cars      1806675.68            20059
# Trucks and Buses  1111559.19            10579
# Motorcycles       1103512.19            11080
# Planes             969323.42            10636
# Ships              700039.22             7989
# Trains             226243.47             2712

# %%
dic={'SALES':"Sales By Each Productline",
     'QUANTITYORDERED':'Quantity Ordered By Productline'}
z=['SALES',"QUANTITYORDERED"]
fig,ax=plt.subplots(2,1)
fig.set_size_inches((12,8))
for i, (column,title) in enumerate(dic.items()):
    sns.barplot(data=df_merge,ax=ax[i],x=z[i],y="PRODUCTLINE",palette='dark:salmon_r')
    ax[i].legend().remove()
    ax[i].set_title(title)
    ax[i].set_ylabel('')
    ax[i].set_xlabel('')
    ax[i].legend().remove()
    ax[i].legend().set_visible(False)
    for n,v in enumerate(df_merge['SALES']):
        ax[0].text(v + 1,n,f'{v:.0f}$',va='center')
    for n,v in enumerate(df_merge['QUANTITYORDERED']):
        ax[1].text(v + 1,n,f'{v:.0f}',va='center')

# Display the plot
fig.suptitle('Sales and Quantity ordered by Each Productline',fontsize=15)
plt.show()
plt.tight_layout()
# Out:
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\1900396486.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_merge,ax=ax[i],x=z[i],y="PRODUCTLINE",palette='dark:salmon_r')
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\1900396486.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax[i].legend().remove()
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\1900396486.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax[i].legend().remove()
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\1900396486.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax[i].legend().set_visible(False)
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\1900396486.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_merge,ax=ax[i],x=z[i],y="PRODUCTLINE",palette='dark:salmon_r')
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\1900396486.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax[i].legend().remove()
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\1900396486.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax[i].legend().remove()
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\1900396486.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax[i].legend().set_visible(False)

# %%
df_clean
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH    SALES   ORDERDATE  \
# 0           10107               30      95.70  2871.00  24/02/2018
# 1           10121               34      81.35  2765.90  07/05/2018
# 2           10134               41      94.74  3884.34  01/07/2018
# 3           10145               45      83.26  3746.70  25/08/2018
# 4           10168               36      96.66  3479.76  28/10/2018
# ...           ...              ...        ...      ...         ...
# 2742        10350               20     112.22  2244.40  02/12/2019
# 2743        10373               29     137.19  3978.51  31/01/2020
# 2744        10386               43     125.99  5417.57  01/03/2020
# 2745        10397               34      62.24  2116.16  28/03/2020
# 2746        10414               47      65.52  3079.44  06/05/2020
#
#       DAYS_SINCE_LASTORDER    STATUS  PRODUCTLINE  MSRP  \
# 0                      828   Shipped  Motorcycles    95
# 1                      757   Shipped  Motorcycles    95
# 2                      703   Shipped  Motorcycles    95
# 3                      649   Shipped  Motorcycles    95
# 4                      586   Shipped  Motorcycles    95
# ...                    ...       ...          ...   ...
# 2742                  2924   Shipped        Ships    54
# 2743                  2865   Shipped        Ships    54
# 2744                  2836  Resolved        Ships    54
# 2745                  2810   Shipped        Ships    54
# 2746                  2772   On Hold        Ships    54
#
#                  CUSTOMERNAME             PHONE        CITY  COUNTRY  \
# 0           Land of Toys Inc.        2125557818         NYC      USA
# 1          Reims Collectables        26.47.1555       Reims   France
# 2             Lyon Souveniers  +33 1 46 62 7555       Paris   France
# 3           Toys4GrownUps.com        6265557265    Pasadena      USA
# 4        Technics Stores Inc.        6505556809  Burlingame      USA
# ...                       ...               ...         ...      ...
# 2742    Euro Shopping Channel    (91) 555 94 44      Madrid    Spain
# 2743  Oulu Toy Supplies, Inc.        981-443655        Oulu  Finland
# 2744    Euro Shopping Channel    (91) 555 94 44      Madrid    Spain
# 2745             Alpha Cognac        61.77.6555    Toulouse   France
# 2746        Gifts4AllAges.com        6175559555      Boston      USA
#
#      CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0                 Yu             Kwai    Small
# 1            Henriot             Paul    Small
# 2           Da Cunha           Daniel   Medium
# 3              Young            Julie   Medium
# 4             Hirano             Juri   Medium
# ...              ...              ...      ...
# 2742          Freyre            Diego    Small
# 2743       Koskitalo           Pirkko   Medium
# 2744          Freyre            Diego   Medium
# 2745          Roulet          Annette    Small
# 2746         Yoshido             Juri   Medium
#
# [2747 rows x 16 columns]

# %%
df_c=pd.DataFrame(df_clean.groupby('COUNTRY')[['SALES','QUANTITYORDERED']].sum().sort_values(by='SALES',ascending=False))
df_c
# Out:
#                   SALES  QUANTITYORDERED
# COUNTRY
# USA          3355575.69            33020
# Spain        1215686.92            12429
# France       1110916.52            11090
# Australia     630623.10             6246
# UK            478880.46             5013
# Italy         374674.31             3773
# Finland       329581.91             3192
# Norway        307463.70             2842
# Singapore     288488.41             2760
# Denmark       245637.15             2197
# Canada        224078.56             2293
# Germany       220472.09             2148
# Sweden        210014.21             2006
# Austria       202062.53             1974
# Japan         188167.81             1842
# Switzerland   117713.56             1078
# Belgium       108412.62             1074
# Philippines    94015.73              961
# Ireland        57756.43              490

# %%
# top 6 Skill Selling Country

top_6=df_c.head(6)
top_6
# Out:
#                 SALES  QUANTITYORDERED
# COUNTRY
# USA        3355575.69            33020
# Spain      1215686.92            12429
# France     1110916.52            11090
# Australia   630623.10             6246
# UK          478880.46             5013
# Italy       374674.31             3773

# %%
top_6
# Out:
#                 SALES  QUANTITYORDERED
# COUNTRY
# USA        3355575.69            33020
# Spain      1215686.92            12429
# France     1110916.52            11090
# Australia   630623.10             6246
# UK          478880.46             5013
# Italy       374674.31             3773

# %%
dic={'SALES':'Top 6 SALES By Country',
     'QUANTITYORDERED':'Top 6 Quantity ordered By Country'}
fig,ax=plt.subplots(2,1)
fig.set_size_inches((12,8))
for i,(column,title) in enumerate(dic.items()):
    sns.barplot(top_6,x=z[i],ax=ax[i],y="COUNTRY",palette='dark:salmon_r')
    ax[i].legend().remove()
    ax[i].set_title(title)
    ax[i].set_ylabel('')
    ax[i].set_xlabel('')
    ax[i].legend().remove()
    ax[i].legend().set_visible(False)
    for n,v in enumerate(df_merge['SALES']):
        ax[0].text(v + 1,n,f'{v:.0f}$',va='center')
    for n,v in enumerate(df_merge['QUANTITYORDERED']):
        ax[1].text(v + 1,n,f'{v:.0f}',va='center')

# Display the plot
fig.suptitle('Sales and Quantity ordered by Top 6 Country',fontsize=15)
plt.show()
plt.tight_layout()
# Out:
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\14036923.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(top_6,x=z[i],ax=ax[i],y="COUNTRY",palette='dark:salmon_r')
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\14036923.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax[i].legend().remove()
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\14036923.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax[i].legend().remove()
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\14036923.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax[i].legend().set_visible(False)
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\14036923.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(top_6,x=z[i],ax=ax[i],y="COUNTRY",palette='dark:salmon_r')
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\14036923.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax[i].legend().remove()
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\14036923.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax[i].legend().remove()
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\14036923.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax[i].legend().set_visible(False)

# %%
df_clean
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH    SALES   ORDERDATE  \
# 0           10107               30      95.70  2871.00  24/02/2018
# 1           10121               34      81.35  2765.90  07/05/2018
# 2           10134               41      94.74  3884.34  01/07/2018
# 3           10145               45      83.26  3746.70  25/08/2018
# 4           10168               36      96.66  3479.76  28/10/2018
# ...           ...              ...        ...      ...         ...
# 2742        10350               20     112.22  2244.40  02/12/2019
# 2743        10373               29     137.19  3978.51  31/01/2020
# 2744        10386               43     125.99  5417.57  01/03/2020
# 2745        10397               34      62.24  2116.16  28/03/2020
# 2746        10414               47      65.52  3079.44  06/05/2020
#
#       DAYS_SINCE_LASTORDER    STATUS  PRODUCTLINE  MSRP  \
# 0                      828   Shipped  Motorcycles    95
# 1                      757   Shipped  Motorcycles    95
# 2                      703   Shipped  Motorcycles    95
# 3                      649   Shipped  Motorcycles    95
# 4                      586   Shipped  Motorcycles    95
# ...                    ...       ...          ...   ...
# 2742                  2924   Shipped        Ships    54
# 2743                  2865   Shipped        Ships    54
# 2744                  2836  Resolved        Ships    54
# 2745                  2810   Shipped        Ships    54
# 2746                  2772   On Hold        Ships    54
#
#                  CUSTOMERNAME             PHONE        CITY  COUNTRY  \
# 0           Land of Toys Inc.        2125557818         NYC      USA
# 1          Reims Collectables        26.47.1555       Reims   France
# 2             Lyon Souveniers  +33 1 46 62 7555       Paris   France
# 3           Toys4GrownUps.com        6265557265    Pasadena      USA
# 4        Technics Stores Inc.        6505556809  Burlingame      USA
# ...                       ...               ...         ...      ...
# 2742    Euro Shopping Channel    (91) 555 94 44      Madrid    Spain
# 2743  Oulu Toy Supplies, Inc.        981-443655        Oulu  Finland
# 2744    Euro Shopping Channel    (91) 555 94 44      Madrid    Spain
# 2745             Alpha Cognac        61.77.6555    Toulouse   France
# 2746        Gifts4AllAges.com        6175559555      Boston      USA
#
#      CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0                 Yu             Kwai    Small
# 1            Henriot             Paul    Small
# 2           Da Cunha           Daniel   Medium
# 3              Young            Julie   Medium
# 4             Hirano             Juri   Medium
# ...              ...              ...      ...
# 2742          Freyre            Diego    Small
# 2743       Koskitalo           Pirkko   Medium
# 2744          Freyre            Diego   Medium
# 2745          Roulet          Annette    Small
# 2746         Yoshido             Juri   Medium
#
# [2747 rows x 16 columns]

# %%
df_clean['STATUS'].unique()
# Out:
# array(['Shipped', 'Disputed', 'In Process', 'Cancelled', 'On Hold',
#        'Resolved'], dtype=object)

# %%
#productline Status by quantity

# %%
df_status=pd.DataFrame(df_clean.groupby('STATUS')['QUANTITYORDERED'].sum().sort_values(ascending=False))
df_status
# Out:
#             QUANTITYORDERED
# STATUS
# Shipped               88764
# Cancelled              2038
# On Hold                1879
# Resolved               1660
# In Process             1490
# Disputed                597

# %%
# Create a bar plot
fig, ax = plt.subplots(1, 1)
sns.barplot(data=df_status, x='QUANTITYORDERED', y='STATUS', palette='dark:salmon_r')

# Add title
plt.title('Status of the Total Ordered Product')

# Annotate each bar with the quantity
for n, v in enumerate(df_status['QUANTITYORDERED']):
    ax.text(v + 1, n, f'{v:.0f}', va='center')

# Adjust layout and show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\903201838.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_status, x='QUANTITYORDERED', y='STATUS', palette='dark:salmon_r')

# %%
# Top 6 Sale and Quantity Ordered by Customers \
top6=df_clean.groupby('CUSTOMERNAME')[['QUANTITYORDERED','SALES']].sum().sort_values(by='SALES',ascending=False).head(6)
top6
# Out:
#                               QUANTITYORDERED      SALES
# CUSTOMERNAME
# Euro Shopping Channel                    9327  912294.11
# Mini Gifts Distributors Ltd.             6366  654858.06
# Australian Collectors, Co.               1926  200995.41
# Muscle Machine Inc                       1775  197736.94
# La Rochelle Gifts                        1832  180124.90
# Dragon Souveniers, Ltd.                  1524  172989.68

# %%
dic={'QUANTITYORDERED':'Top 6 customers by Quantity Ordered',
    'SALES': "Top 6 customers by Sales"}
fig,ax=plt.subplots(2,1)
fig.set_size_inches(12,8)
for i,(column,title) in enumerate(dic.items()):
    sns.barplot(data=top6,ax=ax[i],y='CUSTOMERNAME',x=column,palette='dark:salmon_r')
    ax[i].legend().remove()
    ax[i].set_title(title)
    ax[i].set_ylabel('')
    ax[i].set_xlabel('')
    ax[i].legend().remove()
    ax[i].legend().set_visible(False)
    for n,v in enumerate(top6['QUANTITYORDERED']):
        ax[0].text(v + 1,n,f'{v:.0f}',va='center')
    for n,v in enumerate(top6['SALES']):
        ax[1].text(v + 1,n,f'{v:.0f}$',va='center')
# Out:
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\2121391157.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top6,ax=ax[i],y='CUSTOMERNAME',x=column,palette='dark:salmon_r')
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\2121391157.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax[i].legend().remove()
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\2121391157.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax[i].legend().remove()
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\2121391157.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax[i].legend().set_visible(False)
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\2121391157.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top6,ax=ax[i],y='CUSTOMERNAME',x=column,palette='dark:salmon_r')
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\2121391157.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax[i].legend().remove()
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\2121391157.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax[i].legend().remove()
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10288\2121391157.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax[i].legend().set_visible(False)

# %%
x = df_clean['QUANTITYORDERED']
y = df_clean['SALES']

plt.figure(figsize=(8, 6))
plt.scatter(x, y)
plt.title('Order Quantity vs sales')
plt.xlabel('Order Quantity')
plt.ylabel('Sales')
plt.show()

# %%
from scipy.stats import pearsonr

correlation, p_value = pearsonr(x, y)
print(f'Correlation coefficient: {correlation:.2f}')
print (p_value)
# Out:
# Correlation coefficient: 0.55
# 3.375473491292281e-220

# %%
df_clean
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH    SALES   ORDERDATE  \
# 0           10107               30      95.70  2871.00  24/02/2018
# 1           10121               34      81.35  2765.90  07/05/2018
# 2           10134               41      94.74  3884.34  01/07/2018
# 3           10145               45      83.26  3746.70  25/08/2018
# 4           10168               36      96.66  3479.76  28/10/2018
# ...           ...              ...        ...      ...         ...
# 2742        10350               20     112.22  2244.40  02/12/2019
# 2743        10373               29     137.19  3978.51  31/01/2020
# 2744        10386               43     125.99  5417.57  01/03/2020
# 2745        10397               34      62.24  2116.16  28/03/2020
# 2746        10414               47      65.52  3079.44  06/05/2020
#
#       DAYS_SINCE_LASTORDER    STATUS  PRODUCTLINE  MSRP  \
# 0                      828   Shipped  Motorcycles    95
# 1                      757   Shipped  Motorcycles    95
# 2                      703   Shipped  Motorcycles    95
# 3                      649   Shipped  Motorcycles    95
# 4                      586   Shipped  Motorcycles    95
# ...                    ...       ...          ...   ...
# 2742                  2924   Shipped        Ships    54
# 2743                  2865   Shipped        Ships    54
# 2744                  2836  Resolved        Ships    54
# 2745                  2810   Shipped        Ships    54
# 2746                  2772   On Hold        Ships    54
#
#                  CUSTOMERNAME             PHONE        CITY  COUNTRY  \
# 0           Land of Toys Inc.        2125557818         NYC      USA
# 1          Reims Collectables        26.47.1555       Reims   France
# 2             Lyon Souveniers  +33 1 46 62 7555       Paris   France
# 3           Toys4GrownUps.com        6265557265    Pasadena      USA
# 4        Technics Stores Inc.        6505556809  Burlingame      USA
# ...                       ...               ...         ...      ...
# 2742    Euro Shopping Channel    (91) 555 94 44      Madrid    Spain
# 2743  Oulu Toy Supplies, Inc.        981-443655        Oulu  Finland
# 2744    Euro Shopping Channel    (91) 555 94 44      Madrid    Spain
# 2745             Alpha Cognac        61.77.6555    Toulouse   France
# 2746        Gifts4AllAges.com        6175559555      Boston      USA
#
#      CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0                 Yu             Kwai    Small
# 1            Henriot             Paul    Small
# 2           Da Cunha           Daniel   Medium
# 3              Young            Julie   Medium
# 4             Hirano             Juri   Medium
# ...              ...              ...      ...
# 2742          Freyre            Diego    Small
# 2743       Koskitalo           Pirkko   Medium
# 2744          Freyre            Diego   Medium
# 2745          Roulet          Annette    Small
# 2746         Yoshido             Juri   Medium
#
# [2747 rows x 16 columns]

# %%
grouped_data=df_clean.groupby("MSRP")[['SALES','QUANTITYORDERED']].sum().reset_index()
grouped_data
# Out:
#     MSRP      SALES  QUANTITYORDERED
# 0     33   46973.95              807
# 1     35   47235.48              983
# 2     37   44961.92              870
# 3     40   40114.43              801
# 4     41   31739.40              708
# ..   ...        ...              ...
# 75   173  145332.04              921
# 76   193  158202.48              850
# 77   194  128880.66              797
# 78   207  168585.32              973
# 79   214  179815.23              899
#
# [80 rows x 3 columns]

# %%
# Correlation Analysis
correlation = np.corrcoef(grouped_data['MSRP'], grouped_data['SALES'])[0, 1]
print(f'Correlation between MSRP and Total Sales: {correlation:.2f}')
# Out:
# Correlation between MSRP and Total Sales: 0.46

# %%
# Scatter Plot

plt.gcf().set_size_inches(12,8)
plt.scatter(grouped_data['MSRP'], grouped_data['SALES'], color='blue')
plt.title('MSRP vs Total Sales')
plt.xlabel('MSRP')
plt.ylabel('Total Sales')
plt.grid()

# %%
# Line Graph
plt.plot(grouped_data['MSRP'], grouped_data['QUANTITYORDERED'], marker='o', color='orange')
plt.title('MSRP vs Total Quantity Ordered')
plt.xlabel('MSRP')
plt.ylabel('Total Quantity Ordered')

plt.tight_layout()
plt.show()

# %%
#.Order Frequency 
#To examine how often customers place orders and the average days between orders:
order_freq=df_clean.groupby("CUSTOMERNAME").agg(Number_of_Orders=('ORDERNUMBER', 'count')).reset_index()
order_freq
# Out:
#                    CUSTOMERNAME  Number_of_Orders
# 0                AV Stores, Co.                51
# 1                  Alpha Cognac                20
# 2            Amica Models & Co.                26
# 3       Anna's Decorations, Ltd                46
# 4             Atelier graphique                 7
# ..                          ...               ...
# 84              Vida Sport, Ltd                31
# 85              Vitachrome Inc.                25
# 86     Volvo Model Replicas, Co                19
# 87  West Coast Collectables Co.                13
# 88            giftsbymail.co.uk                26
#
# [89 rows x 2 columns]

# %%
average_days_between_orders = df_clean.groupby('CUSTOMERNAME').agg(
    Average_Days_Between_Orders=('DAYS_SINCE_LASTORDER', 'mean')
).reset_index()

# %%
average_days_between_orders
# Out:
#                    CUSTOMERNAME  Average_Days_Between_Orders
# 0                AV Stores, Co.                  1803.803922
# 1                  Alpha Cognac                  2236.200000
# 2            Amica Models & Co.                  1318.615385
# 3       Anna's Decorations, Ltd                  1463.586957
# 4             Atelier graphique                  1424.428571
# ..                          ...                          ...
# 84              Vida Sport, Ltd                  1362.935484
# 85              Vitachrome Inc.                  1591.880000
# 86     Volvo Model Replicas, Co                  1319.789474
# 87  West Coast Collectables Co.                  1714.769231
# 88            giftsbymail.co.uk                  2180.807692
#
# [89 rows x 2 columns]

# %%
order_freq=order_freq.merge(average_days_between_orders,how='left',on='CUSTOMERNAME')
order_freq
# Out:
#                    CUSTOMERNAME  Number_of_Orders  Average_Days_Between_Orders
# 0                AV Stores, Co.                51                  1803.803922
# 1                  Alpha Cognac                20                  2236.200000
# 2            Amica Models & Co.                26                  1318.615385
# 3       Anna's Decorations, Ltd                46                  1463.586957
# 4             Atelier graphique                 7                  1424.428571
# ..                          ...               ...                          ...
# 84              Vida Sport, Ltd                31                  1362.935484
# 85              Vitachrome Inc.                25                  1591.880000
# 86     Volvo Model Replicas, Co                19                  1319.789474
# 87  West Coast Collectables Co.                13                  1714.769231
# 88            giftsbymail.co.uk                26                  2180.807692
#
# [89 rows x 3 columns]

# %%
sns.histplot(data=order_freq['Number_of_Orders'])
plt.title('Histogram of Order Frequency per Customer')
plt.xlabel('Number of Orders')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sns.displot(data=order_freq['Average_Days_Between_Orders'],fill=True, label='Plot of Average Days Between Orders',color="orange")
plt.gcf().set_size_inches(12,8)
plt.title("Plot of Average Days Between Orders")
# Out:
# Text(0.5, 1.0, 'Plot of Average Days Between Orders')

# %%
order_freq
# Out:
#                    CUSTOMERNAME  Number_of_Orders  Average_Days_Between_Orders
# 0                AV Stores, Co.                51                  1803.803922
# 1                  Alpha Cognac                20                  2236.200000
# 2            Amica Models & Co.                26                  1318.615385
# 3       Anna's Decorations, Ltd                46                  1463.586957
# 4             Atelier graphique                 7                  1424.428571
# ..                          ...               ...                          ...
# 84              Vida Sport, Ltd                31                  1362.935484
# 85              Vitachrome Inc.                25                  1591.880000
# 86     Volvo Model Replicas, Co                19                  1319.789474
# 87  West Coast Collectables Co.                13                  1714.769231
# 88            giftsbymail.co.uk                26                  2180.807692
#
# [89 rows x 3 columns]

# %%
top_5=order_freq.sort_values(by='Average_Days_Between_Orders',ascending=False).head(3)
top_5
# Out:
#                          CUSTOMERNAME  Number_of_Orders  \
# 31                 Enaco Distributors                23
# 35                   Gift Ideas Corp.                19
# 65  Royal Canadian Collectables, Ltd.                26
#
#     Average_Days_Between_Orders
# 31                  2483.913043
# 35                  2419.894737
# 65                  2366.730769

# %%
sns.boxplot(order_freq['Average_Days_Between_Orders'])
plt.title('Box Plot of Average Days Between Orders')
plt.xlabel('Average Days Between Orders')
plt.tight_layout()
plt.show()

# %%
df_clean
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH    SALES   ORDERDATE  \
# 0           10107               30      95.70  2871.00  24/02/2018
# 1           10121               34      81.35  2765.90  07/05/2018
# 2           10134               41      94.74  3884.34  01/07/2018
# 3           10145               45      83.26  3746.70  25/08/2018
# 4           10168               36      96.66  3479.76  28/10/2018
# ...           ...              ...        ...      ...         ...
# 2742        10350               20     112.22  2244.40  02/12/2019
# 2743        10373               29     137.19  3978.51  31/01/2020
# 2744        10386               43     125.99  5417.57  01/03/2020
# 2745        10397               34      62.24  2116.16  28/03/2020
# 2746        10414               47      65.52  3079.44  06/05/2020
#
#       DAYS_SINCE_LASTORDER    STATUS  PRODUCTLINE  MSRP  \
# 0                      828   Shipped  Motorcycles    95
# 1                      757   Shipped  Motorcycles    95
# 2                      703   Shipped  Motorcycles    95
# 3                      649   Shipped  Motorcycles    95
# 4                      586   Shipped  Motorcycles    95
# ...                    ...       ...          ...   ...
# 2742                  2924   Shipped        Ships    54
# 2743                  2865   Shipped        Ships    54
# 2744                  2836  Resolved        Ships    54
# 2745                  2810   Shipped        Ships    54
# 2746                  2772   On Hold        Ships    54
#
#                  CUSTOMERNAME             PHONE        CITY  COUNTRY  \
# 0           Land of Toys Inc.        2125557818         NYC      USA
# 1          Reims Collectables        26.47.1555       Reims   France
# 2             Lyon Souveniers  +33 1 46 62 7555       Paris   France
# 3           Toys4GrownUps.com        6265557265    Pasadena      USA
# 4        Technics Stores Inc.        6505556809  Burlingame      USA
# ...                       ...               ...         ...      ...
# 2742    Euro Shopping Channel    (91) 555 94 44      Madrid    Spain
# 2743  Oulu Toy Supplies, Inc.        981-443655        Oulu  Finland
# 2744    Euro Shopping Channel    (91) 555 94 44      Madrid    Spain
# 2745             Alpha Cognac        61.77.6555    Toulouse   France
# 2746        Gifts4AllAges.com        6175559555      Boston      USA
#
#      CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0                 Yu             Kwai    Small
# 1            Henriot             Paul    Small
# 2           Da Cunha           Daniel   Medium
# 3              Young            Julie   Medium
# 4             Hirano             Juri   Medium
# ...              ...              ...      ...
# 2742          Freyre            Diego    Small
# 2743       Koskitalo           Pirkko   Medium
# 2744          Freyre            Diego   Medium
# 2745          Roulet          Annette    Small
# 2746         Yoshido             Juri   Medium
#
# [2747 rows x 16 columns]

# %%
df_clean['STATUS'].unique()
# Out:
# array(['Shipped', 'Disputed', 'In Process', 'Cancelled', 'On Hold',
#        'Resolved'], dtype=object)

# %%
returns_data = df_clean[df_clean['STATUS'] == 'Cancelled'].groupby('PRODUCTLINE').agg(
    Number_of_Returns=('ORDERNUMBER', 'count')).reset_index()

total_orders_data = df_clean.groupby('PRODUCTLINE').agg(
    Total_Orders=('ORDERNUMBER', 'count'),
    Total_Sales=('SALES', 'sum')).reset_index()

# Merge both DataFrames
merged_data = pd.merge(total_orders_data, returns_data, on='PRODUCTLINE', how='left').fillna(0)

# Calculate Return Rate
merged_data['Return_Rate'] = merged_data['Number_of_Returns'] / merged_data['Total_Orders']
merged_data
# Out:
#         PRODUCTLINE  Total_Orders  Total_Sales  Number_of_Returns  Return_Rate
# 0      Classic Cars           949   3842868.54               16.0     0.016860
# 1       Motorcycles           313   1103512.19                0.0     0.000000
# 2            Planes           304    969323.42               12.0     0.039474
# 3             Ships           230    700039.22               18.0     0.078261
# 4            Trains            77    226243.47                1.0     0.012987
# 5  Trucks and Buses           295   1111559.19                0.0     0.000000
# 6      Vintage Cars           579   1806675.68               13.0     0.022453

# %%
# Profitability Analysis: Calculate Profitability (Total Sales - Returns)
merged_data['Revenue_Lost_Due_To_Returns'] = merged_data['Number_of_Returns'] * (merged_data['Total_Sales'] / merged_data['Total_Orders'])
merged_data['Profitability'] = merged_data['Total_Sales'] - merged_data['Revenue_Lost_Due_To_Returns']

# Display the results
print(merged_data[['PRODUCTLINE', 'Return_Rate', 'Profitability']])
# Out:
#         PRODUCTLINE  Return_Rate  Profitability
# 0      Classic Cars     0.016860   3.778078e+06
# 1       Motorcycles     0.000000   1.103512e+06
# 2            Planes     0.039474   9.310607e+05
# 3             Ships     0.078261   6.452535e+05
# 4            Trains     0.012987   2.233052e+05
# 5  Trucks and Buses     0.000000   1.111559e+06
# 6      Vintage Cars     0.022453   1.766111e+06

# %%
# Bar Chart for Return Rates
plt.figure(figsize=(12, 6))
plt.bar(merged_data['PRODUCTLINE'], merged_data['Return_Rate'], color='orange')
plt.title('Return Rate by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Return Rate')
plt.xticks(rotation=45)
plt.grid(axis='y')

# %%
# Pie Chart for Total Revenue Lost Due to Returns
plt.figure(figsize=(12,12))
plt.pie(merged_data['Revenue_Lost_Due_To_Returns'], labels=merged_data['PRODUCTLINE'], autopct='%1.1f%%', startangle=90)
plt.title('Proportion of Total Revenue Lost Due to Returns by Product Category')

plt.tight_layout()
plt.show()
